# %% [markdown]
# <a href="https://colab.research.google.com/github/lenamugep/Projectphase1/blob/main/student1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Aviation Data Analysis Project
##  Importing Necessary Libraries
### Description:
import the essential libraries for data analysis and visualization.
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
import os
# List files to confirm their names
os.listdir()

# Remove duplicate files (if they exist)
try

# Confirm remaining files
os.listdir()

df = pd.read_csv('AviationData (1).csv', encoding='latin-1')
df.head()
# Out:
# <ipython-input-31-f559cf5503ec>:16: DtypeWarning: Columns (6,7,28) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('AviationData (1).csv', encoding='latin-1')
#          Event.Id Investigation.Type Accident.Number  Event.Date  \
# 0  20001218X45444           Accident      SEA87LA080  1948-10-24
# 1  20001218X45447           Accident      LAX94LA336  1962-07-19
# 2  20061025X01555           Accident      NYC07LA005  1974-08-30
# 3  20001218X45448           Accident      LAX96LA321  1977-06-19
# 4  20041105X01764           Accident      CHI79FA064  1979-08-02
#
#           Location        Country   Latitude  Longitude Airport.Code  \
# 0  MOOSE CREEK, ID  United States        NaN        NaN          NaN
# 1   BRIDGEPORT, CA  United States        NaN        NaN          NaN
# 2    Saltville, VA  United States  36.922223 -81.878056          NaN
# 3       EUREKA, CA  United States        NaN        NaN          NaN
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 88889 entries, 0 to 88888
# Data columns (total 31 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Event.Id                88889 non-null  object
#  1   Investigation.Type      88889 non-null  object
#  2   Accident.Number         88889 non-null  object
#  3   Event.Date              88889 non-null  object
#  4   Location                88837 non-null  object
#  5   Country                 88663 non-null  object
#  6   Latitude                34382 non-null  object
#  7   Longitude               34373 non-null  object
#  8   Airport.Code            50132 non-null  object
#  9   Airport.Name            52704 non-null  object
#  10  Injury.Severity         87889 non-null  object
#  11  Aircraft.damage         85695 non-null  object
#  12  Aircraft.Category       32287 non-null  object
#  13  Registration.Number     87507 non-null  object
# ...

# %%
df.isnull().sum()
# Out:
# Event.Id                      0
# Investigation.Type            0
# Accident.Number               0
# Event.Date                    0
# Location                     52
# Country                     226
# Latitude                  54507
# Longitude                 54516
# Airport.Code              38757
# Airport.Name              36185
# Injury.Severity            1000
# Aircraft.damage            3194
# Aircraft.Category         56602
# Registration.Number        1382
# Make                         63
# Model                        92
# Amateur.Built               102
# Number.of.Engines          6084
# Engine.Type                7096
# FAR.Description           56866
# Schedule                  76307
# Purpose.of.flight          6192
# Air.carrier               72241
# Total.Fatal.Injuries      11401
# Total.Serious.Injuries    12510
# Total.Minor.Injuries      11933
# Total.Uninjured            5912
# Weather.Condition          4492
# Broad.phase.of.flight     27165
# ...

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.drop_duplicates(inplace=True)

# %%
df.dropna(thresh=5, inplace=True)  # Keep rows with at least 5 non-null values

# %%
df.columns
# Out:
# Index(['Event.Id', 'Investigation.Type', 'Accident.Number', 'Event.Date',
#        'Location', 'Country', 'Latitude', 'Longitude', 'Airport.Code',
#        'Airport.Name', 'Injury.Severity', 'Aircraft.damage',
#        'Aircraft.Category', 'Registration.Number', 'Make', 'Model',
#        'Amateur.Built', 'Number.of.Engines', 'Engine.Type', 'FAR.Description',
#        'Schedule', 'Purpose.of.flight', 'Air.carrier', 'Total.Fatal.Injuries',
#        'Total.Serious.Injuries', 'Total.Minor.Injuries', 'Total.Uninjured',
#        'Weather.Condition', 'Broad.phase.of.flight', 'Report.Status',
#        'Publication.Date'],
#       dtype='object')

# %%
df['Country'].value_counts().head(5)
# Out:
# Country
# United States     82248
# Brazil              374
# Canada              359
# Mexico              358
# United Kingdom      344
# Name: count, dtype: int64

# %%
# Check the most common phase of flight when accidents occur df['Broad.phase.of.flight'].value_counts()

# %%
df['Model'].value_counts().head(5) # Find the most common aircraft models.
# Out:
# Model
# 152          2367
# 172          1756
# 172N         1164
# PA-28-140     932
# 150           829
# Name: count, dtype: int64

# %%
df.drop(['Investigation.Type', 'Accident.Number', 'Report.Status'], axis=1, inplace=True)

# %%
# Fix inconsistent Formatting in Categorical Data:
df['Country'] = df['Country'].str.title()
df['Aircraft.damage'] = df['Aircraft.damage'].str.lower()

# %%
# Top 10 Countries with the Most Accidents
# Data Visualization
plt.figure(figsize=(12, 6))
df['Country'].value_counts().head(10).plot(kind='bar', color='skyblue')
plt.title('Top 10 Countries with the Most Aviation Accidents')
plt.xlabel('Country')
plt.ylabel('Number of Accidents')
plt.xticks(rotation=45)
plt.show()

# %%
# Visualizing Accident Severity Distribution
plt.figure(figsize=(8, 6))
sns.countplot(x='Injury.Severity', data=df, order=df['Injury.Severity'].value_counts().index, palette='viridis')
plt.title('Distribution of Injury Severity')
plt.xlabel('Injury Severity')
plt.ylabel('Count')
plt.xticks(rotation=45)
plt.show()
# Out:
# <ipython-input-66-d960fbde86e1>:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x='Injury.Severity', data=df, order=df['Injury.Severity'].value_counts().index, palette='viridis')

# %%
plt.figure(figsize=(8, 6))
sns.heatmap(df[['Total.Fatal.Injuries', 'Total.Serious.Injuries', 'Total.Minor.Injuries', 'Total.Uninjured']].corr(), annot=True, cmap='coolwarm')
plt.title('Correlation Between Injury Types')
plt.show()

# %%
#Top Aircraft Models Involved in Accidents
top_models = df['Model'].value_counts().nlargest(10)

# Plot the top models
top_models.plot(kind='bar', figsize=(12, 6), color='skyblue')
plt.title('Top 10 Aircraft Models Involved in Accidents')
plt.xlabel('Aircraft Model')
plt.ylabel('Number of Accidents')
plt.show()

# %% [markdown]
# ## Conclusions:
# - Most accidents occurred during takeoff and landing phases.
# - Poor weather conditions were a contributing factor in many cases.
# - Human error and mechanical failure were leading causes of accidents.
# - Recommended improving pilot training and maintenance protocols.
